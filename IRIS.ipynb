# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\madva\appdata\local\programs\python\python313\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\madva\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.2.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\madva\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\madva\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\madva\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv("C:/Users/madva/Desktop/Projects/Iris IOMP/IRIS.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = df.drop(columns = ["Id"])

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df["SepalLengthCm"].hist()
# Out:
# <Axes: >

# %%
df["SepalWidthCm"].hist()
# Out:
# <Axes: >

# %%
df["PetalLengthCm"].hist()
# Out:
# <Axes: >

# %%
df["PetalWidthCm"].hist()
# Out:
# <Axes: >

# %%
colors = ["red","orange","blue"]
species = ["Iris-virginica","Iris-versicolor","Iris-setosa"]

# %%
for i in range(3):
     x = df[df["Species"] == species[i]]
     plt.scatter(x["SepalLengthCm"],x["SepalWidthCm"], c = colors[i], label = species[i])
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.legend()

# %%
for i in range(3):
     x = df[df["Species"] == species[i]]
     plt.scatter(x["PetalLengthCm"],x["PetalWidthCm"], c = colors[i], label = species[i])
plt.xlabel("PetalLengthCm")
plt.ylabel("PetalWidthCm")
plt.legend()

# %%
for i in range(3):
     x = df[df["Species"] == species[i]]
     plt.scatter(x["SepalLengthCm"],x["PetalLengthCm"], c = colors[i], label = species[i])
plt.xlabel("SepalLengthCm")
plt.ylabel("PetalLengthCm")
plt.legend()

# %%
for i in range(3):
     x = df[df["Species"] == species[i]]
     plt.scatter(x["SepalWidthCm"],x["PetalWidthCm"], c = colors[i], label = species[i])
plt.xlabel("SepalWidthCm")
plt.ylabel("PetalWidthCm")
plt.legend()

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.corr(numeric_only=True)
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
corr = df.corr(numeric_only=True)
fig,ax = plt.subplots(figsize = (5,4))
sns.heatmap(corr,annot = True,ax = ax,cmap = "coolwarm")
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
import pickle

# %%
X = df.drop(columns = ["Species"])

# %%
Y = df["Species"]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.30)

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
print("Logistic Regression Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# Logistic Regression Accuracy:  97.77777777777777

# %%
model.fit(x_train.values,y_train.values)
# Out:
# LogisticRegression()

# %%
print("Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# Accuracy:  97.77777777777777

# %%
model = KNeighborsClassifier()
model.fit(x_train,y_train)
print("K-nearest neighbours Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# K-nearest neighbours Accuracy:  97.77777777777777

# %%
model.fit(x_train.values,y_train.values)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# Accuracy:  97.77777777777777

# %%
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
print("Decision tree Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# Decision tree Accuracy:  95.55555555555556

# %%
model.fit(x_train.values,y_train.values)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# Accuracy:  95.55555555555556

# %%
pip install pickle
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for pickle

# %%
import pickle

# %%
filename = "saved_model.sav"
pickle.dump(model,open(filename,"wb"))

# %%
filename = "saved_model.csv"
try:
   with open(filename,"wb") as file:
        pickle.dump(model,file)
   print("Model saved successfully")
except Exception as e:
   print(f"Error saving the model:{e}")
# Out:
# Model saved successfully

# %%
load_model = pickle.load(open(filename,"rb"))

# %%
load_model.predict([[6.0,2.2,4.0,1.0]])
# Out:
# array(['Iris-versicolor'], dtype=object)

# %%
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
x_test.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 112            6.8           3.0            5.5           2.1
# 36             5.5           3.5            1.3           0.2
# 65             6.7           3.1            4.4           1.4
# 51             6.4           3.2            4.5           1.5
# 58             6.6           2.9            4.6           1.3

# %%
load_model.predict([[4,3,1,5]])
# Out:
# array(['Iris-versicolor'], dtype=object)
